# %% [markdown]
# <a href="https://colab.research.google.com/github/MarekSroka/SDA_projekty/blob/main/MS_project_activity_type.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# Rodzaj aktywności:
# - Walking
#
# - Walking Upstairs
#
# - Walking Downstairs
#
# - Sitting
#
# - Standing
#
# - Laying
#
# na podstawie danych z telefonu

# %% [markdown]
# For each record in the dataset it is provided:
# - Triaxial acceleration from the accelerometer (total acceleration) and the estimated body acceleration.
# - Triaxial Angular velocity from the gyroscope.
# - A 561-feature vector with time and frequency domain variables.
# - Its activity label.
# - An identifier of the subject who carried out the experiment.

# %% [markdown]
# # EDA

# %%
dataset = pd.read_csv('drive/MyDrive/ML_uczenie_nadz_klasyfikacja/activity_type.csv')

# %%
dataset.shape
# Out:
# (7352, 563)

# %%
pd.set_option('display.max_columns', None)
dataset.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %% [markdown]
# **Groups of features:**
#
# -tBodyAcc-XYZ
#
# -tGravityAcc-XYZ
#
# -tBodyAccJerk-XYZ
#
# -tBodyGyro-XYZ
#
# -tBodyGyroJerk-XYZ
#
# -tBodyAccMag
#
# -tGravityAccMag
#
# -tBodyAccJerkMag
#
# -tBodyGyroMag
#
# -tBodyGyroJerkMag
#
# -fBodyAcc-XYZ
#
# -fBodyAccJerk-XYZ
#
# -fBodyGyro-XYZ
#
# -fBodyAccMag
#
# -fBodyAccJerkMag
#
# -fBodyGyroMag
#
# -fBodyGyroJerkMag
#
#  - subject - number of people who takes apart in research
#  - Activity - which is our target

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7352 entries, 0 to 7351
# Columns: 563 entries, tBodyAcc-mean()-X to Activity
# dtypes: float64(561), int64(1), object(1)
# memory usage: 31.6+ MB

# %%
print(dataset['subject'].unique())
print()
print(dataset['subject'].nunique())
print()
print(dataset['subject'].value_counts())
# Out:
# [ 1  3  5  6  7  8 11 14 15 16 17 19 21 22 23 25 26 27 28 29 30]
#
# 21
#
# 25    409
# 21    408
# 26    392
# 30    383
# 28    382
# 27    376
# 23    372
# 17    368
# 16    366
# 19    360
# 1     347
# 29    344
# 3     341
# 15    328
# 6     325
# 14    323
# 22    321
# 11    316
# 7     308
# 5     302
# 8     281
# Name: subject, dtype: int64

# %%
print(dataset['Activity'].unique())
print()
print(dataset['Activity'].nunique())
print()
print(dataset['Activity'].value_counts())
# Out:
# ['STANDING' 'SITTING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS'
#  'WALKING_UPSTAIRS']
#
# 6
#
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
activity = dataset.copy()
y = activity.pop('Activity')
y[:5]
# Out:
# 0    STANDING
# 1    STANDING
# 2    STANDING
# 3    STANDING
# 4    STANDING
# Name: Activity, dtype: object

# %%
X = activity
X[:5]
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
X.drop(['subject'], axis=1, inplace=True)
X[:5]
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
X.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
X.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %%
X.duplicated().sum()
# Out:
# 0

# %%
X.isnull().values.sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

plt.figure(figsize=(15, 10))

sns.displot(y)
plt.xticks(rotation=90)

plt.show()

# %%
dataset.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
plt.figure(figsize=(16, 9))

sns.set_style('whitegrid')
sns.countplot(x='subject',hue='Activity', data = dataset)
plt.legend(loc='upper right')
plt.show()

# %%
display('STANDING', dataset.loc[dataset['Activity']=='STANDING'].head())
display('SITTING', dataset.loc[dataset['Activity']=='SITTING'].head())
display('LAYING', dataset.loc[dataset['Activity']=='LAYING'].head())
display('WALKING', dataset.loc[dataset['Activity']=='WALKING'].head())
display('WALKING_UPSTAIRS', dataset.loc[dataset['Activity']=='WALKING_UPSTAIRS'].head())
display('WALKING_DOWNSTAIRS', dataset.loc[dataset['Activity']=='WALKING_DOWNSTAIRS'].head())
# Out:
# 'STANDING'
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %% [markdown]
# We can estimate some set of variables from the above signals. ie.,
#
# We will estimate the following properties on each and every signal that we recorded so far: mean(), std(), mad(),max(), min(),energy(), entropy(), iqr(), correlation(), angle() etc
#
# jerk= rate of change of acceleration
#
# acc=rate of change of velocity
#
# mag=magnitude

# %%
# # 1. Coefficient tBodyAccMag-mean() - mean of magnitude of acceleration has difference value between stationary and moving activities

# %%
dataset.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
print(dataset['Activity'].unique())
# Out:
# ['STANDING' 'SITTING' 'LAYING' 'WALKING' 'WALKING_DOWNSTAIRS'
#  'WALKING_UPSTAIRS']

# %%
df1 = dataset[dataset['Activity']=='STANDING']
df2 = dataset[dataset['Activity']=='SITTING']
df3 = dataset[dataset['Activity']=='LAYING']

df4 = dataset[dataset['Activity']=='WALKING']
df5 = dataset[dataset['Activity']=='WALKING_DOWNSTAIRS']
df6 = dataset[dataset['Activity']=='WALKING_UPSTAIRS']

# %%
df2.shape
# Out:
# (1286, 563)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,9))

plt.subplot(221)
plt.title('Stationary activities')
sns.distplot(df1['tBodyAccMag-mean()'],color = 'r',hist = False, label = 'STANDING')
sns.distplot(df2['tBodyAccMag-mean()'],color = 'm',hist = False, label = 'SITTING')
sns.distplot(df3['tBodyAccMag-mean()'],color = 'c',hist = False, label = 'LAYING')
plt.xlabel('Acceleration Magnitude mean')
plt.axis([-1.01, -0.5, 0, 35])

plt.legend()

plt.subplot(222)
plt.title('Moving activities')
sns.distplot(df4['tBodyAccMag-mean()'],color = 'g',hist = False, label = 'WALKING')
sns.distplot(df5['tBodyAccMag-mean()'],color = 'y',hist = False, label = 'WALKING_DOWNSTAIRS')
sns.distplot(df6['tBodyAccMag-mean()'],color = 'k',hist = False, label = 'WALKING_UPSTAIRS')
plt.xlabel('Acceleration Magnitude mean')

plt.legend()

plt.show()

# %%
# 2. Boxplot for angle gravity mean

# %%
# X

plt.figure(figsize=(10,10))
sns.boxplot(x='Activity', y='angle(X,gravityMean)', data=dataset, showfliers=False)
plt.ylabel('Body acceleration Magnitude mean')
plt.xlabel('ACTIVITY')
plt.xticks(rotation=45)
plt.show()

# %%
# Y
plt.figure(figsize=(10,10))
sns.boxplot(x='Activity', y='angle(Y,gravityMean)', data=dataset, showfliers=False)
plt.ylabel('Body acceleration Magnitude mean')
plt.xlabel('ACTIVITY')
plt.xticks(rotation=45)
plt.show()

# %%
# 3. Boxplot of body accuracy magnitude mean

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='Activity', y='tBodyAccMag-mean()', data=dataset, showfliers=False)
plt.ylabel('Acceleration Magnitude mean')
plt.xlabel('ACTIVITY')
plt.xticks(rotation=45)
plt.show()

# %%
stop
# CorrMatrix

# %%
plt.figure(figsize=(30, 30))

corrMatrix = X.corr()
sns.heatmap(X.corr())

plt.show()

# %% [markdown]
# # RANDOM FOREST with the whole dataset

# %%
X.shape
# Out:
# (7352, 561)

# %%
y[:5]
# Out:
# 0    STANDING
# 1    STANDING
# 2    STANDING
# 3    STANDING
# 4    STANDING
# Name: Activity, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=23)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import RandomizedSearchCV
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.model_selection import HalvingRandomSearchCV

from sklearn.ensemble import RandomForestClassifier

# %%
print(X.columns)
len(X.columns)
# Out:
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-meanFreq()', 'fBodyBodyGyroJerkMag-skewness()',
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)'],
#       dtype='object', length=561)
# 561

# %%
numeric_transformer = Pipeline(steps=[
    ('standardscaler', StandardScaler())
])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, X.columns),
    ])

final_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                 ('RFC', RandomForestClassifier())])

print(final_pipeline.get_params().keys())
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'preprocessor', 'RFC', 'preprocessor__n_jobs', 'preprocessor__remainder', 'preprocessor__sparse_threshold', 'preprocessor__transformer_weights', 'preprocessor__transformers', 'preprocessor__verbose', 'preprocessor__verbose_feature_names_out', 'preprocessor__num', 'preprocessor__num__memory', 'preprocessor__num__steps', 'preprocessor__num__verbose', 'preprocessor__num__standardscaler', 'preprocessor__num__standardscaler__copy', 'preprocessor__num__standardscaler__with_mean', 'preprocessor__num__standardscaler__with_std', 'RFC__bootstrap', 'RFC__ccp_alpha', 'RFC__class_weight', 'RFC__criterion', 'RFC__max_depth', 'RFC__max_features', 'RFC__max_leaf_nodes', 'RFC__max_samples', 'RFC__min_impurity_decrease', 'RFC__min_samples_leaf', 'RFC__min_samples_split', 'RFC__min_weight_fraction_leaf', 'RFC__n_estimators', 'RFC__n_jobs', 'RFC__oob_score', 'RFC__random_state', 'RFC__verbose', 'RFC__warm_start'])

# %%
param = {
    'RFC__bootstrap': [True],
    'RFC__max_depth': [80, 90, 100, 110, 130],
    'RFC__max_features': [2, 3, 5, 7],
    'RFC__min_samples_leaf': [3, 4, 5, 6, 8],
    'RFC__min_samples_split': [8, 10, 12, 14],
    'RFC__n_estimators': [100, 200, 300, 1000],
    'RFC__criterion' :['gini', 'entropy']
}

RFC_gridsearch = HalvingRandomSearchCV(final_pipeline, 
                                       param,
                                       scoring='neg_mean_squared_error',
                                       cv=15,
                                       verbose=10,
                                      n_jobs=-1)

RFC_gridsearch.fit(X_train, y_train)
print('\nBest hyperparameter:', RFC_gridsearch.best_params_)

rf_model = RFC_gridsearch.best_estimator_
# Out:
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 4
# min_resources_: 180
# max_resources_: 4925
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 27
# n_resources: 180
# Fitting 15 folds for each of 27 candidates, totalling 405 fits
# ----------
# iter: 1
# n_candidates: 9
# n_resources: 540
# Fitting 15 folds for each of 9 candidates, totalling 135 fits
# ----------
# iter: 2
# n_candidates: 3
# n_resources: 1620
# Fitting 15 folds for each of 3 candidates, totalling 45 fits
# ----------
# iter: 3
# n_candidates: 1
# n_resources: 4860
# Fitting 15 folds for each of 1 candidates, totalling 15 fits
#
# Best hyperparameter: {'RFC__n_estimators': 1000, 'RFC__min_samples_split': 12, 'RFC__min_samples_leaf': 8, 'RFC__max_features': 2, 'RFC__max_depth': 100, 'RFC__criterion': 'gini', 'RFC__bootstrap': True}

# %%
y_test_pred=rf_model.predict(X_test)
y_test_pred
# Out:
# array(['WALKING_UPSTAIRS', 'LAYING', 'SITTING', ..., 'WALKING_UPSTAIRS',
#        'WALKING_DOWNSTAIRS', 'WALKING_UPSTAIRS'], dtype=object)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_test_pred))
# Out:
#                     precision    recall  f1-score   support
#
#             LAYING       0.99      0.99      0.99       478
#            SITTING       0.96      0.89      0.92       419
#           STANDING       0.91      0.96      0.93       440
#            WALKING       0.97      0.98      0.98       397
# WALKING_DOWNSTAIRS       0.97      0.92      0.94       324
#   WALKING_UPSTAIRS       0.93      0.97      0.95       369
#
#           accuracy                           0.95      2427
#          macro avg       0.95      0.95      0.95      2427
#       weighted avg       0.95      0.95      0.95      2427

# %%
from sklearn import metrics

print('\nConfusion matrix')
fig, ax = plt.subplots(figsize=(12, 8))
metrics.plot_confusion_matrix(rf_model, X_test, y_test,
                              cmap=plt.cm.Blues, normalize=None, ax=ax)
ax.tick_params(axis='x', rotation=45)
plt.show()
# Out:
# Confusion matrix

# %% [markdown]
# # Logistic regression model to choose features

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=2022)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
params = {'C': [0.01, 0.1, 1, 10, 100]}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(penalty='l1', solver='liblinear', random_state=2022, n_jobs=-1)

gs_model = GridSearchCV(model, 
                        param_grid=params, 
                        cv=15,
                        n_jobs=-1)

gs_model.fit(X_train, y_train)

# %%
model = LogisticRegression(**gs_model.best_params_, penalty='l1', solver='liblinear')
model.fit(X_train, y_train)

# %%
coef = model.coef_[0]
print(coef.dtype)
coef

# %%
# X_train[:5]

# %%
# The coefficient values equating to 0 are the redundant features and can be removed from the training sample.

# %%
coef = model.coef_[0]
imp_features = pd.Series(X.columns)[list(coef!=0)]
imp_features

# %%
imp = list(imp_features)
imp

# %%
X_mod = X[imp]
X_mod.shape

# %%
print('Amount of redundant features:', sum(model.coef_[0]==0))
print('Redundant feature names:', list(pd.Series(X.columns)[list(coef!=0)]))

# %% [markdown]
# # Processing on chosen features

# %%
dataset.head()

# %%
# zmienić na końcu  -- chosen_feature = imp

chosen_feature = ['tBodyAcc-correlation()-X,Y',
 'tBodyAcc-correlation()-Y,Z',
 'tGravityAcc-mean()-X',
 'tGravityAcc-std()-X',
 'tGravityAcc-mad()-X',
 'tGravityAcc-max()-X',
 'tGravityAcc-min()-X',
 'tGravityAcc-sma()',
 'tGravityAcc-energy()-X',
 'tGravityAcc-energy()-Y',
 'tGravityAcc-energy()-Z',
 'tGravityAcc-iqr()-X',
 'tBodyGyro-correlation()-X,Y',
 'tBodyGyro-correlation()-Y,Z',
 'tBodyGyroJerk-arCoeff()-Y,2',
 'fBodyGyro-meanFreq()-Y',
 'fBodyGyro-skewness()-X',
 'fBodyGyro-kurtosis()-X',
 'angle(X,gravityMean)']

# %%
len(chosen_feature)

# %%
X = dataset[chosen_feature]
X.head()

# %%
y.head()

# %% [markdown]
# # RANDOM FOREST after dataset redundancy

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=23)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import RandomizedSearchCV
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingGridSearchCV
from sklearn.model_selection import HalvingRandomSearchCV

from sklearn.ensemble import RandomForestClassifier

# %%
final_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                 ('RFC', RandomForestClassifier())])

print(final_pipeline.get_params().keys())

# %%
param = {
    'RFC__bootstrap': [True],
    'RFC__max_depth': [80, 90, 100, 110, 130],
    'RFC__max_features': [2, 3],
    'RFC__min_samples_leaf': [3, 4, 5, 6],
    'RFC__min_samples_split': [8, 10, 12],
    'RFC__n_estimators': [100, 200, 300, 1000],
    'RFC__criterion' :['gini', 'entropy']
}
RFC_gridsearch = HalvingRandomSearchCV(final_pipeline, 
                                       param,
                                       scoring='neg_mean_squared_error',
                                       cv=15,
                                       verbose=10,
                                      n_jobs=-1)

RFC_gridsearch.fit(X_train, y_train)
print('\nBest hyperparameter:', RFC_gridsearch.best_params_)

rf_model = RFC_gridsearch.best_estimator_

# %%
y_test_pred=rf_model.predict(X_test)
y_test_pred

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_test_pred))

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test,  y_test_pred)

ax = sns.heatmap(cm, annot=True, cmap='Blues', fmt='.0f')

ax.set_title('Confusion Matrix\n\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ')
plt.show()

# %%
# zrobić implementację

# print('\nConfusion matrix')
#     fig, ax = plt.subplots(figsize=(12, 8))

#     metrics.plot_confusion_matrix(models[name]['model'], X_test, y_test,
#                                   cmap=plt.cm.Blues, normalize=None, ax=ax)
   
#     ax.tick_params(axis='x', rotation=45)
#     plt.show()

# %%
# sprawdzić

# %% [markdown]
# BSZ
#
# Korelacja pomiędzy kategoryczną cechą a numeryczną a nastepnie cechy najbardziej
#
# Przy regresji logitycznej skorzystać z regularyzacji
#
# Zredukować wielowymiarowość
#
# Regresja logistyczna moze być wykorzystana do selekcji cech
#
# point biserial correlation

# %%
# funkcja

# %%
metrics_dataframe = pd.DataFrame(columns = ['Model', 'Accuracy', 'F1_score'])
metrics_dataframe

# %% [markdown]
# # końcowe uwagi BSZ:
#
# 1. Nie ma sensu do Random Foresta do robić standardscalera - nie ma sensu tego robić.
#
# 2. Sprawdzić po selekcji cech, jakie mają wpływ na dataframe.
#
#
# **2. Zrobić funkcję do printowania danych.**
# 3. Wybrane
#
# dodatkowo
# 3. Można wybierać cechy poprzez Pipeline - wówczas należy zrobić to dodatkowym kodem w preprocesorze / Hyper Opt - wwóczas jest robony zamiast Gridsearch
